# %% [markdown]
# ![logo-2.png](attachment:logo-2.png)

# %% [markdown]
# In this project, we will analyze human resources data by performing data wrangling & EDA.
#
# We will learn how to:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # CODING TASK #1. IMPORT DATASET AND PERFORM BASIC STATISTICAL DATA ANALYSIS

# %% [markdown]
# - **Import Pandas Library**
#
# - **Force Pandas to display all rows and columns**
#
# - **Let's read a CSV file using Pandas as follows**
#
# - **Let's obtain the datatype**
#
# - **you can view the first couple of rows using .head()**
#
# - **you can view the last couple of rows using .tail()**
#
# - **Calculate the average values for employee_df dataframe**
#
# - **35 features in total**
#
# - **Obtain a Statistical Summary about the data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
warnings.warn("thisnwill not show")

# %%
df=pd.read_csv("Human_Resources.csv")

# %%
df.sample(10)
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1049   30         5301.0        No      Travel_Rarely       1358
# 188    34         9547.0        No  Travel_Frequently       1069
# 431    54         3780.0        No      Travel_Rarely        548
# 1450   35         8837.0        No      Travel_Rarely       1146
# 763    34         2220.0        No      Travel_Rarely       1333
# 477    50        18200.0        No  Travel_Frequently       1246
# 283    55         5415.0        No      Travel_Rarely        147
# 784    38         8823.0        No      Travel_Rarely        330
# 622    32         4403.0        No      Travel_Rarely        117
# 568    55        19859.0       Yes      Travel_Rarely        725
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 1049                   Sales                16          1     Life Sciences
# 188   Research & Development                 2          1     Life Sciences
# ...

# %%
df.head(2)
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
#
#    EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0              1  ...                         1             80
# 1              1  ...                         4             80
#
#   StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                0                  8                      0                1
# 1                1                 10                      3                3
#
#   YearsAtCompany  YearsInCurrentRole YearsSinceLastPromotion  \
# 0              6                   4                       0
# ...

# %%
pd.set_option('display.max_columns', 500)
df.head(10)
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
# 3   33         2909.0        No  Travel_Frequently       1392
# 4   27         3468.0        No      Travel_Rarely        591
# 5   32         3068.0        No  Travel_Frequently       1005
# 6   59            NaN        No      Travel_Rarely       1324
# 7   30         2693.0        No      Travel_Rarely       1358
# 8   38         9526.0        No  Travel_Frequently        216
# 9   36         5237.0        No      Travel_Rarely       1299
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# ...

# %%
df.tail(2)
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  EmployeeNumber  EnvironmentSatisfaction Gender  \
# 1468              1          2065.0                        4   Male
# 1469              1          2068.0                        2   Male
#
#       HourlyRate  JobInvolvement  JobLevel                JobRole  \
# 1468          63               2         2        Sales Executive
# 1469          82               4         2  Laboratory Technician
#
#       JobSatisfaction MaritalStatus  MonthlyRate  NumCompaniesWorked Over18  \
# ...

# %%
df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# MonthlyIncome             1467.0   6505.155419  4711.297846  1009.0  2911.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1469.0   1025.556161   601.646166     1.0   492.00
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# ...

# %%
df.mean()
# Out:
# Age                            36.923810
# MonthlyIncome                6505.155419
# DailyRate                     802.485714
# DistanceFromHome                9.192517
# Education                       2.912925
# EmployeeCount                   1.000000
# EmployeeNumber               1025.556161
# EnvironmentSatisfaction         2.721769
# HourlyRate                     65.891156
# JobInvolvement                  2.729932
# JobLevel                        2.063946
# JobSatisfaction                 2.728571
# MonthlyRate                 14310.966621
# NumCompaniesWorked              2.693197
# PercentSalaryHike              15.206263
# PerformanceRating               3.153165
# RelationshipSatisfaction        2.712245
# StandardHours                  80.000000
# StockOptionLevel                0.793878
# TotalWorkingYears              11.279592
# TrainingTimesLastYear           2.799320
# WorkLifeBalance                 2.761224
# YearsAtCompany                  7.008163
# ...

# %%
df.describe(include="all").T
# Out:
#                            count unique                     top  freq  \
# Age                       1470.0    NaN                     NaN   NaN
# MonthlyIncome             1467.0    NaN                     NaN   NaN
# Attrition                   1470      2                      No  1233
# BusinessTravel              1470      3           Travel_Rarely  1043
# DailyRate                 1470.0    NaN                     NaN   NaN
# Department                  1469      3  Research & Development   960
# DistanceFromHome          1470.0    NaN                     NaN   NaN
# Education                 1470.0    NaN                     NaN   NaN
# EducationField              1469      6           Life Sciences   606
# EmployeeCount             1470.0    NaN                     NaN   NaN
# EmployeeNumber            1469.0    NaN                     NaN   NaN
# EnvironmentSatisfaction   1470.0    NaN                     NaN   NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   MonthlyIncome             1467 non-null   float64
#  2   Attrition                 1470 non-null   object
#  3   BusinessTravel            1470 non-null   object
#  4   DailyRate                 1470 non-null   int64
#  5   Department                1469 non-null   object
#  6   DistanceFromHome          1470 non-null   int64
#  7   Education                 1470 non-null   int64
#  8   EducationField            1469 non-null   object
#  9   EmployeeCount             1470 non-null   int64
#  10  EmployeeNumber            1469 non-null   float64
#  11  EnvironmentSatisfaction   1470 non-null   int64
#  12  Gender                    1469 non-null   object
# ...

# %% [markdown]
# **PRACTICE OPPORTUNITY #1:**
# - **Calculate the mean, maximum and minimum employee age considered in this study using a different strategy**

# %%
df[df.Age == df.Age.min()]
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 296    18         1420.0       Yes      Travel_Rarely        230
# 301    18         1200.0        No      Travel_Rarely        812
# 457    18         1878.0       Yes  Travel_Frequently       1306
# 727    18         1051.0        No         Non-Travel        287
# 828    18         1904.0       Yes         Non-Travel        247
# 972    18         1611.0        No         Non-Travel       1124
# 1153   18         1569.0       Yes  Travel_Frequently        544
# 1311   18         1514.0        No         Non-Travel       1431
#
#                   Department  DistanceFromHome  Education EducationField  \
# 296   Research & Development                 3          3  Life Sciences
# 301                    Sales                10          3        Medical
# 457                    Sales                 5          3      Marketing
# 727   Research & Development                 5          2  Life Sciences
# ...

# %%
df[df.Age == df.Age.max()]
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 411    60        19566.0        No      Travel_Rarely        422
# 427    60        10266.0        No  Travel_Frequently       1499
# 536    60         5405.0        No      Travel_Rarely       1179
# 879    60         5220.0        No      Travel_Rarely        696
# 1209   60        10883.0        No      Travel_Rarely        370
#
#                   Department  DistanceFromHome  Education EducationField  \
# 411   Research & Development                 7          3  Life Sciences
# 427                    Sales                28          3      Marketing
# 536                    Sales                16          4      Marketing
# 879                    Sales                 7          4      Marketing
# 1209  Research & Development                 1          4        Medical
#
#       EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# ...

# %%
Age = df["Age"].agg(["min","max","mean"])
Age
# Out:
# min     18.00000
# max     60.00000
# mean    36.92381
# Name: Age, dtype: float64

# %%
df.Age.nsmallest()
# Out:
# 296    18
# 301    18
# 457    18
# 727    18
# 828    18
# Name: Age, dtype: int64

# %%
df.max(axis=0)['Age']
# Out:
# 60

# %%
df["Age"].nlargest()
# Out:
# 411     60
# 427     60
# 536     60
# 879     60
# 1209    60
# Name: Age, dtype: int64

# %%
 df.Age.mean()
# Out:
# 36.923809523809524

# %%
oldest   =df.loc[df['Age'].idxmax()]
youngest =df.loc[df['Age'].idxmin()]
youngest
# Out:
# Age                                             18
# MonthlyIncome                               1420.0
# Attrition                                      Yes
# BusinessTravel                       Travel_Rarely
# DailyRate                                      230
# Department                  Research & Development
# DistanceFromHome                                 3
# Education                                        3
# EducationField                       Life Sciences
# EmployeeCount                                    1
# EmployeeNumber                               405.0
# EnvironmentSatisfaction                          3
# Gender                                        Male
# HourlyRate                                      54
# JobInvolvement                                   3
# JobLevel                                         1
# JobRole                      Laboratory Technician
# JobSatisfaction                                  3
# ...

# %%
oldest
# Out:
# Age                                             60
# MonthlyIncome                              19566.0
# Attrition                                       No
# BusinessTravel                       Travel_Rarely
# DailyRate                                      422
# Department                  Research & Development
# DistanceFromHome                                 7
# Education                                        3
# EducationField                       Life Sciences
# EmployeeCount                                    1
# EmployeeNumber                               549.0
# EnvironmentSatisfaction                          1
# Gender                                      Female
# HourlyRate                                      41
# JobInvolvement                                   3
# JobLevel                                         5
# JobRole                                    Manager
# JobSatisfaction                                  1
# ...

# %%
df[["Age"]].describe().T
# Out:
#       count      mean       std   min   25%   50%   75%   max
# Age  1470.0  36.92381  9.135373  18.0  30.0  36.0  43.0  60.0

# %% [markdown]
# # CODING TASK #2. DEALING WITH MISSING DATA

# %% [markdown]
# - **Let's locate rows that have Null values**
#
# - **Notice Row index 6 has many missing values**
#
# - **Let's see the total number of missing elements per column**
#
# - **Drop any row that contains a Null value**
#
# - **Note that the size of the dataframe has been reduced by 7 elements from 1470 to 1463**
#
# - **Notice that row 1 for example is no longer existing!**
#
# - **Let's check if we still have any missing values**
#
# - **Let's explore an alternative (smarter) method to deal with missing values**
#
# - **Let's read the raw data again using Pandas as follows**
#
# - **Calculate the average monthly income**
#
# - **You can use Fillna to fill a given column with a certain value**

# %%
#df.loc[df['this_column'].isnull()] spesifik kolumdaki NaN degerleri getirmek icin..
df.loc[df.isnull().any(axis=1)]
# Out:
#      Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1     49            NaN        No  Travel_Frequently        279
# 6     59            NaN        No      Travel_Rarely       1324
# 7     30         2693.0        No      Travel_Rarely       1358
# 17    22         2935.0        No         Non-Travel       1123
# 23    21         1232.0        No      Travel_Rarely        391
# 103   34         4809.0        No      Travel_Rarely        665
# 947   52            NaN       Yes      Travel_Rarely       1030
#
#                  Department  DistanceFromHome  Education EducationField  \
# 1    Research & Development                 8          1  Life Sciences
# 6    Research & Development                 3          3            NaN
# 7                       NaN                24          1  Life Sciences
# 17   Research & Development                16          2        Medical
# 23   Research & Development                15          2  Life Sciences
# ...

# %%
row_6=df.loc[6]       # Notice Row index 6 has many missing values
row_6
# Out:
# Age                                             59
# MonthlyIncome                                  NaN
# Attrition                                       No
# BusinessTravel                       Travel_Rarely
# DailyRate                                     1324
# Department                  Research & Development
# DistanceFromHome                                 3
# Education                                        3
# EducationField                                 NaN
# EmployeeCount                                    1
# EmployeeNumber                                 NaN
# EnvironmentSatisfaction                          3
# Gender                                         NaN
# HourlyRate                                      81
# JobInvolvement                                   4
# JobLevel                                         1
# JobRole                                        NaN
# JobSatisfaction                                  1
# ...

# %%
df.isnull().sum()[df.isnull().sum()>0]   #  Let's see the total number of missing elements per column
# Out:
# MonthlyIncome        3
# Department           1
# EducationField       1
# EmployeeNumber       1
# Gender               1
# JobRole              1
# MaritalStatus        1
# MonthlyRate          2
# PercentSalaryHike    1
# PerformanceRating    1
# dtype: int64

# %%
df.dropna(inplace=True)  # Drop any row that contains a Null value

# %%
df.isnull().sum()
# Out:
# Age                         0
# MonthlyIncome               0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
import missingno as msno

# %%
msno.matrix(df);

# %% [markdown]
# # #Note that the size of the dataframe has been reduced by 7 elements from 1470 to 1463. Notice that row 1 for example is no longer existing!

# %%
df.shape
# Out:
# (1463, 35)

# %%
df=pd.read_csv("Human_Resources.csv")

# %% [markdown]
# # Calculate the average monthly income. You can use Fillna to fill a given column with a certain value

# %%
df.MonthlyIncome.mean()
# Out:
# 6505.155419222904

# %%
df_medn=df.MonthlyIncome.median()
df_medn
# Out:
# 4908.0

# %%
df["MonthlyIncome"].fillna(df_medn, inplace=True)
df["MonthlyIncome"].isnull().sum()
# Out:
# 0

# %%
df['Department'] = df['Department'].fillna(method='ffill')
print(df["Department"])
# Out:
# 0                        Sales
# 1       Research & Development
# 2       Research & Development
# 3       Research & Development
# 4       Research & Development
#                  ...
# 1465    Research & Development
# 1466    Research & Development
# 1467    Research & Development
# 1468                     Sales
# 1469    Research & Development
# Name: Department, Length: 1470, dtype: object

# %%
df['Department'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **PRACTICE OPPORTUNITY #2:**
# - **Calculate the median monthly rate. Use the calculated median values to fill out missing data. Confirm that the process is successful**

# %%
df_median=df.MonthlyRate.median()
df_median
# Out:
# 14235.5

# %%
df["MonthlyRate"].fillna(df_median, inplace=True)
df["MonthlyRate"].isnull().any()
# Out:
# False

# %%
df.isnull().sum()[df.isnull().sum()>0]
# Out:
# EducationField       1
# EmployeeNumber       1
# Gender               1
# JobRole              1
# MaritalStatus        1
# PercentSalaryHike    1
# PerformanceRating    1
# dtype: int64

# %%
PerfR_M=df.PerformanceRating.median()
PerfR_M
# Out:
# 3.0

# %%
df.PerformanceRating.fillna(PerfR_M,inplace=True)
df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49         4908.0        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
df.PerformanceRating.isnull().sum()
# Out:
# 0

# %%
mean_val = df['PercentSalaryHike'].mean()    # Maas artis yuzdesi
mean_val
# Out:
# 15.206262763784888

# %%
df['PercentSalaryHike'].fillna(mean_val, inplace=True)
df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49         4908.0        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
df['PercentSalaryHike'].isnull().any()
# Out:
# False

# %%
df.isnull().sum()[df.isnull().sum()>0]
# Out:
# EducationField    1
# EmployeeNumber    1
# Gender            1
# JobRole           1
# MaritalStatus     1
# dtype: int64

# %%
df.JobeRole=df["JobRole"].fillna(method="ffill")
df.JobeRole.isnull().sum()
# Out:
# 0

# %%
mode = df['Gender'].mode()[0]
df['Gender'].fillna(mode, inplace=True)

# %%
df['Gender'].isnull().sum()
# Out:
# 0

# %%
mode = df['MaritalStatus'].mode()[0]
df['MaritalStatus'].fillna(mode, inplace=True)

# %%
df['MaritalStatus'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()[df.isnull().sum()>0]
# Out:
# EducationField    1
# EmployeeNumber    1
# JobRole           1
# dtype: int64

# %%
sns.boxplot(data=df, x="JobRole", y="HourlyRate")
plt.xticks(rotation=90)
plt.xlabel("Job Role")
plt.ylabel("Hourly Pay Rate")
plt.title("Hourly Rates by Job Role")
plt.show()

# %%
sns.barplot( x=df["OverTime"],y=df["WorkLifeBalance"],ci=None,)
plt.xlabel("OverTime")
plt.ylabel("WorkLifeBalance")
plt.title("OverTime by WorkLifeBalance")
plt.show()

# %%
sns.boxplot(data=df, x="JobLevel", y="MonthlyRate")
plt.xticks(rotation=90)
plt.xlabel("Job Level")
plt.ylabel("Monthly Pay Rate")
plt.title("Monthly Rates by Job Level")
plt.show()

# %%
df.HourlyRate.unique()
# Out:
# array([ 94,  61,  92,  56,  40,  79,  81,  67,  44,  84,  49,  31,  93,
#         50,  51,  80,  96,  78,  45,  82,  53,  83,  58,  72,  48,  42,
#         41,  86,  97,  75,  33,  37,  73,  98,  36,  47,  71,  30,  43,
#         99,  59,  95,  57,  76,  87,  66,  55,  32,  52,  70,  62,  64,
#         63,  60, 100,  46,  39,  77,  35,  91,  54,  34,  90,  65,  88,
#         85,  89,  68,  69,  74,  38], dtype=int64)

# %%
sns.barplot( x=df["OverTime"],y=df["PerformanceRating"])
plt.xlabel("OverTime")
plt.ylabel("PerformanceRating")
plt.title("OverTime by Performance")
plt.show()

# %%
  #Çalışanlar Arasındaki Eşitsizlikleri Anlamak icin
df.groupby("JobRole")["MonthlyIncome"].value_counts()
# Out:
# JobRole                    MonthlyIncome
# Healthcare Representative  5562.0           2
#                            6142.0           2
#                            6811.0           2
#                            9824.0           2
#                            4000.0           1
#                                            ..
# Sales Representative       3931.0           1
#                            4400.0           1
#                            4502.0           1
#                            5405.0           1
#                            6632.0           1
# Name: MonthlyIncome, Length: 1425, dtype: int64

# %%
sns.barplot(y=df.JobRole, x=df.MonthlyIncome);

# %%
fig, ax = plt.subplots(facecolor="Lightblue",figsize=(10,5))
sns.barplot(x=df.JobLevel, y=df.MonthlyIncome,color="purple",ci=None);

# %%
df.isnull().sum()[df.isnull().sum()>0]
# Out:
# EducationField    1
# EmployeeNumber    1
# JobRole           1
# dtype: int64

# %%
df.groupby("JobRole")["Gender"].value_counts()
# Out:
# JobRole                    Gender
# Healthcare Representative  Male       80
#                            Female     51
# Human Resources            Male       36
#                            Female     16
# Laboratory Technician      Male      174
#                            Female     84
# Manager                    Male       55
#                            Female     47
# Manufacturing Director     Male       73
#                            Female     72
# Research Director          Male       47
#                            Female     33
# Research Scientist         Male      178
#                            Female    114
# Sales Executive            Male      194
#                            Female    132
# Sales Representative       Male       45
#                            Female     38
# Name: Gender, dtype: int64

# %%
print(df['Department'].value_counts()) #How many employees work in each department
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
sns.barplot(x=df["MaritalStatus"], y=df["PerformanceRating"]);

# %%
sns.barplot(x=df["Gender"], y=df["PerformanceRating"]);

# %%
Avg_salary=df.MonthlyIncome.mean()
Avg_salary
# Out:
# 6501.895918367347

# %%
sns.histplot(df.MonthlyIncome, kde=True);

# %%
sns.barplot(x=df["JobLevel"], y=df["JobSatisfaction"])
plt.title("Distribution of Job Satisfaction Ratings")
;
# Out:
# ''

# %%
dept_satisfaction = df.groupby("Department")["JobSatisfaction"].mean().reset_index()
sns.barplot(x="Department", y="JobSatisfaction", data=dept_satisfaction)
plt.xlabel("Department")
plt.ylabel("Average Job Satisfaction")
plt.title("Job Satisfaction by Department");

# %%
sns.barplot(x=df.PerformanceRating,y=df.Department); #her bölümün performansını belirleyerek ve yüksek veya düşük performansa sahip olan bölümleri tanımlayarak insaytlar elde edebilirsiniz.

# %%
sns.barplot(x=df["Department"],y=df["MonthlyIncome"]); # Hangi departmanlar shirket icin daha maliyetli

# %% [markdown]
# # CODING TASK #3: PERFORM ONE-HOT ENCODING [OPTIONAL]

# %% [markdown]
# - **Import the Human Resources data and remove all missing values**
# - **How many unique categories exist in the Education Field column?**
# - **Perform one hot encoding to the Education Field column**

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# **PRACTICE OPPORTUNITY #3 [OPTIONAL]:**
# - **Import the Human Resources data and remove all missing values**
# - **How many unique categories exist in the Education Field column?**
# - **Perform one hot encoding to the Education Field column**

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')
pd.set_option('display.max_columns', 500)
hr_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
hr_df.dropna(inplace=True)

# %%
hr_df.isnull().sum()
# Out:
# Age                         0
# MonthlyIncome               0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
hr_df['EducationField'].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
EducationField_Encoded = pd.get_dummies(hr_df['EducationField'])
print(EducationField_Encoded)
# Out:
#       Human Resources  Life Sciences  Marketing  Medical  Other  \
# 0                   0              1          0        0      0
# 2                   0              0          0        0      1
# 3                   0              1          0        0      0
# 4                   0              0          0        1      0
# 5                   0              1          0        0      0
# ...               ...            ...        ...      ...    ...
# 1465                0              0          0        1      0
# 1466                0              0          0        1      0
# 1467                0              1          0        0      0
# 1468                0              0          0        1      0
# 1469                0              0          0        1      0
#
#       Technical Degree
# 0                    0
# 2                    0
# 3                    0
# 4                    0
# 5                    0
# ...                ...
# 1465                 0
# ...

# %% [markdown]
# # CODING TASK #4: PERFORM SCALING (NORMALIZATION & STANDARDIZATION) [OPTIONAL]

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')
hr_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
hr_df['Age'].values
# Out:
# array([41, 49, 37, ..., 27, 49, 34], dtype=int64)

# %%
hr_df['Age'].max()
# Out:
# 60

# %%
hr_df['Age'].min()
# Out:
# 18

# %%
sns.displot(x=hr_df['Age'],data=hr_df,kind = "hist", kde = True, aspect = 1 ,color="green",);

# %%
# Normalization 
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
hr_df['Age'] = scaler.fit_transform(hr_df['Age'].values.reshape(-1,1))

# %%
hr_df['Age'].sample(10)
# Out:
# 943     0.666667
# 732     0.285714
# 709     0.309524
# 1186    0.404762
# 676     0.404762
# 743     0.976190
# 1039    0.380952
# 258     0.785714
# 314     0.500000
# 179     0.476190
# Name: Age, dtype: float64

# %%
hr_df.describe()
# Out:
#                Age  MonthlyIncome    DailyRate  DistanceFromHome    Education  \
# count  1470.000000    1467.000000  1470.000000       1470.000000  1470.000000
# mean      0.450567    6505.155419   802.485714          9.192517     2.912925
# std       0.217509    4711.297846   403.509100          8.106864     1.024165
# min       0.000000    1009.000000   102.000000          1.000000     1.000000
# 25%       0.285714    2911.000000   465.000000          2.000000     2.000000
# 50%       0.428571    4908.000000   802.000000          7.000000     3.000000
# 75%       0.595238    8378.000000  1157.000000         14.000000     4.000000
# max       1.000000   19999.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1469.000000              1470.000000  1470.000000
# mean             1.0     1025.556161                 2.721769    65.891156
# ...

# %% [markdown]
# **PRACTICE OPPORTUNITY #4 [OPTIONAL]:**
# - **Perform feature scaling by performing standardization (Recall that Standardization is conducted to transform the data to have a mean of zero and standard deviation of 1.**
# - **Perform a sanity check to ensure that the transformation was successful**

# %%
# Standardization
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
hr_df["DailyRate"] = scaler.fit_transform(hr_df["DailyRate"].values.reshape(-1,1))
hr_df["DailyRate"].head(20)
# Out:
# 0     0.742527
# 1    -1.297775
# 2     1.414363
# 3     1.461466
# 4    -0.524295
# 5     0.502054
# 6     1.292887
# 7     1.377177
# 8    -1.453958
# 9     1.230910
# 10    0.016150
# 11   -1.610141
# 12   -0.328446
# 13    1.347427
# 14   -1.734097
# 15    1.454029
# 16   -1.161424
# 17    0.794588
# 18    1.032581
# 19   -1.069697
# Name: DailyRate, dtype: float64

# %%
sns.histplot(x=hr_df["DailyRate"], color="red");

# %%
hr_df.describe()
# Out:
#                Age  MonthlyIncome     DailyRate  DistanceFromHome  \
# count  1470.000000    1467.000000  1.470000e+03       1470.000000
# mean      0.450567    6505.155419  5.075305e-17          9.192517
# std       0.217509    4711.297846  1.000340e+00          8.106864
# min       0.000000    1009.000000 -1.736576e+00          1.000000
# 25%       0.285714    2911.000000 -8.366616e-01          2.000000
# 50%       0.428571    4908.000000 -1.204135e-03          7.000000
# 75%       0.595238    8378.000000  8.788772e-01         14.000000
# max       1.000000   19999.000000  1.726730e+00         29.000000
#
#          Education  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  \
# count  1470.000000         1470.0     1469.000000              1470.000000
# mean      2.912925            1.0     1025.556161                 2.721769
# std       1.024165            0.0      601.646166                 1.093082
# ...

# %% [markdown]
# # CODING TASK #5. PANDAS OPERATIONS/FILTERING

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')

# %% [markdown]
# - **Pick certain rows that satisfy a certain criteria**
#
# - **Pick certain rows that satisfy 2 or more critirea**
#
# - **values that fall between a given range**

# %%
hr_df_1= df[(hr_df["MonthlyIncome"]<2000) & (hr_df["Attrition"]=="Yes")]    # Let's pick certain rows that satisfy 2 
hr_df_1
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 127    19         1675.0       Yes      Travel_Rarely        528
# 177    19         1102.0       Yes      Travel_Rarely        303
# 296    18         1420.0       Yes      Travel_Rarely        230
# 457    18         1878.0       Yes  Travel_Frequently       1306
# 513    20         1009.0       Yes      Travel_Rarely       1362
# 585    23         1601.0       Yes      Travel_Rarely       1243
# 777    21         1416.0       Yes      Travel_Rarely       1334
# 828    18         1904.0       Yes         Non-Travel        247
# 892    19         1859.0       Yes         Non-Travel        504
# 911    25         1118.0       Yes  Travel_Frequently        599
# 1012   31         1359.0       Yes  Travel_Frequently        667
# 1016   31         1261.0       Yes      Travel_Rarely        202
# 1153   18         1569.0       Yes  Travel_Frequently        544
# ...

# %%
#Filter data for employees in the sales department with a salary greater than $19,000
high_sal = df[(df["Department"] == "Research & Development") & (df["MonthlyIncome"] > 19000)]
high_sal.head(10)
# Out:
#      Age  MonthlyIncome Attrition BusinessTravel  DailyRate  \
# 25    53        19094.0        No  Travel_Rarely       1282
# 45    41        19545.0       Yes  Travel_Rarely       1360
# 123   51        19537.0        No  Travel_Rarely        684
# 165   50        19926.0        No  Travel_Rarely       1452
# 186   40        19033.0        No  Travel_Rarely        989
# 190   52        19999.0        No  Travel_Rarely        699
# 231   42        19232.0        No  Travel_Rarely        532
# 244   45        19202.0        No  Travel_Rarely        252
# 257   40        19436.0        No  Travel_Rarely       1416
# 270   55        19045.0        No  Travel_Rarely        452
#
#                  Department  DistanceFromHome  Education    EducationField  \
# 25   Research & Development                 5          3             Other
# 45   Research & Development                12          3  Technical Degree
# 123  Research & Development                 6          3     Life Sciences
# ...

# %% [markdown]
# **PRACTICE OPPORTUNITY #5:**
# - **Using "hr_df" DataFrame, leverage pandas operations to only select high DailyRate individuals (1450+)**
# - **What is the combined Daily Rate for all employees with 1450+?**

# %%
hr_df_1= df[(hr_df["DailyRate"]>1450)]
hr_df_1
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 31     44         6465.0        No      Travel_Rarely       1459
# 52     44         5454.0        No      Travel_Rarely       1488
# 110    51         7484.0        No  Travel_Frequently       1456
# 117    36         9738.0        No  Travel_Frequently       1467
# 155    29         4319.0        No         Non-Travel       1496
# 165    50        19926.0        No      Travel_Rarely       1452
# 172    36         2088.0        No  Travel_Frequently       1480
# 213    51        12490.0        No      Travel_Rarely       1469
# 266    31         5582.0        No      Travel_Rarely       1463
# 278    26         6397.0        No  Travel_Frequently       1479
# 302    28         5661.0        No      Travel_Rarely       1476
# 329    47        18300.0        No      Travel_Rarely       1482
# 373    27         3816.0        No      Travel_Rarely       1469
# ...

# %%
# What is the combined Daily Rate for all employees with 1450+?
hr_df_1["DailyRate"].sum()
# Out:
# 70849

# %% [markdown]
# # CODING TASK #6: PERFORM BASIC EDA ON BOTH CLASSES

# %% [markdown]
# - **It makes sense to drop 'EmployeeCount', 'Standardhours' and 'Over18' since they do not change from one employee to the other**
# - **Let's see how many employees left the company! Let's drop 'EmployeeNumber' as well**
# - **Let's see how many employees left the company!**
# - **View employees who left**

# %%
hr_df = pd.read_csv('Human_Resources.csv')
hr_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
# It makes sense to drop 'EmployeeCount', 'Standardhours' and 'Over18' since they do not change from one employee to the other
hr_df.drop(['EmployeeCount', 'Over18', 'StandardHours'], axis=1, inplace=True)

# %%
hr_df.drop(["EmployeeNumber"],axis=1,inplace=True)    #  Let's drop 'EmployeeNumber' as well

# %%
hr_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
hr_df.Attrition.value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
# Let's see how many employees left the company!
left_df = hr_df[hr_df.Attrition == "Yes"]
left_df.shape[0]
# Out:
# 237

# %%
#View employees who left
print(left_df)
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 14     28         2028.0       Yes      Travel_Rarely        103
# 21     36         3407.0       Yes      Travel_Rarely       1218
# 24     34         2960.0       Yes      Travel_Rarely        699
# ...   ...            ...       ...                ...        ...
# 1438   23         1790.0       Yes  Travel_Frequently        638
# 1442   29         4787.0       Yes      Travel_Rarely       1092
# 1444   56         2339.0       Yes      Travel_Rarely        310
# 1452   50         6728.0       Yes  Travel_Frequently        878
# 1461   50        10854.0       Yes      Travel_Rarely        410
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 0                      Sales                 1          2     Life Sciences
# ...

# %%
sns.barplot(x=hr_df.Attrition,y=hr_df.PerformanceRating);

# %%
# We can infer that monthly income is lower for employees who left their jobs
ax=sns.barplot(x=hr_df.Attrition,y=hr_df.MonthlyIncome,data=hr_df, ci=70) 
plt.title('Employees that left by salary level', fontsize=14);

# %%
# As we see job satisfaction was lower for employees who quit the job
sns.barplot(x=hr_df.Attrition,y=hr_df.JobSatisfaction);

# %%
# Job level was lower for employees who left
sns.barplot(x=hr_df.Attrition,y=hr_df.JobLevel);

# %%
#Filter data for employees in the sales department with a salary greater than $19,000
high_sal = df[(df["Department"] == "Research & Development") & (df["MonthlyIncome"] > 19000)]
high_sal
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 25     53        19094.0        No      Travel_Rarely       1282
# 45     41        19545.0       Yes      Travel_Rarely       1360
# 123    51        19537.0        No      Travel_Rarely        684
# 165    50        19926.0        No      Travel_Rarely       1452
# 186    40        19033.0        No      Travel_Rarely        989
# 190    52        19999.0        No      Travel_Rarely        699
# 231    42        19232.0        No      Travel_Rarely        532
# 244    45        19202.0        No      Travel_Rarely        252
# 257    40        19436.0        No      Travel_Rarely       1416
# 270    55        19045.0        No      Travel_Rarely        452
# 279    50        19144.0        No      Travel_Rarely        797
# 326    39        19272.0        No  Travel_Frequently        672
# 392    54        19406.0        No      Travel_Rarely        821
# ...

# %%
high_sal = df[(df["Department"] == "Sales") & (df["MonthlyIncome"] > 19000)]
high_sal
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate Department  \
# 233    50        19517.0        No      Travel_Rarely        854      Sales
# 237    52        19068.0        No         Non-Travel        771      Sales
# 749    52        19845.0       Yes      Travel_Rarely        266      Sales
# 918    51        19847.0        No  Travel_Frequently        237      Sales
# 1116   55        19586.0        No      Travel_Rarely        685      Sales
# 1126   50        19331.0        No      Travel_Rarely        264      Sales
# 1242   40        19833.0        No      Travel_Rarely        611      Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 233                  1          4        Medical              1
# 237                  2          4  Life Sciences              1
# 749                  2          1      Marketing              1
# 918                  9          3  Life Sciences              1
# ...

# %%
x=df.groupby("MonthlyIncome")["YearsAtCompany"].value_counts()
x
# Out:
# MonthlyIncome  YearsAtCompany
# 1009.0         1                 1
# 1051.0         0                 1
# 1052.0         1                 1
# 1081.0         1                 1
# 1091.0         1                 1
#                                 ..
# 19859.0        5                 1
# 19926.0        5                 1
# 19943.0        5                 1
# 19973.0        21                1
# 19999.0        33                1
# Name: YearsAtCompany, Length: 1452, dtype: int64

# %%
df[(df['TotalWorkingYears'] >= 35) & (df['TotalWorkingYears'] <= 40)]
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 85     56         7260.0        No      Travel_Rarely       1400
# 98     58        13872.0        No      Travel_Rarely        682
# 126    58        10312.0       Yes      Travel_Rarely        147
# 187    55        18722.0        No      Travel_Rarely        692
# 270    55        19045.0        No      Travel_Rarely        452
# 401    56        13212.0        No  Travel_Frequently        906
# 445    55        16835.0        No      Travel_Rarely       1117
# 595    58        19246.0       Yes      Travel_Rarely        286
# 624    53        10934.0        No      Travel_Rarely        661
# 894    54        17779.0        No      Travel_Rarely        685
# 956    56        19717.0        No      Travel_Rarely        206
# 1043   53        16598.0        No      Travel_Rarely        447
# 1116   55        19586.0        No      Travel_Rarely        685
# ...

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   MonthlyIncome             1467 non-null   float64
#  2   Attrition                 1470 non-null   object
#  3   BusinessTravel            1470 non-null   object
#  4   DailyRate                 1470 non-null   int64
#  5   Department                1469 non-null   object
#  6   DistanceFromHome          1470 non-null   int64
#  7   Education                 1470 non-null   int64
#  8   EducationField            1469 non-null   object
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1469 non-null   object
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
# ...

# %%
hr_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %% [markdown]
# **PRACTICE OPPORTUNITY #6:**
# - **Filter the hr_df to only include the employees who stayed in the company**
# - **Generate statistical summary for employees who stayed**
# - **Compare both statistical summaries. What do you infer from the data?**

# %%
stayed_df = hr_df[hr_df['Attrition'] == "No"]
stayed_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1      49            NaN        No  Travel_Frequently        279
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# 5      32         3068.0        No  Travel_Frequently       1005
# 6      59            NaN        No      Travel_Rarely       1324
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 1     Research & Development                 8          1  Life Sciences
# ...

# %%
stayed_df.describe().T
# Out:
#                            count          mean          std     min     25%  \
# Age                       1233.0     37.561233     8.888360    18.0    31.0
# MonthlyIncome             1231.0   6837.504468  4820.415800  1051.0  3211.5
# DailyRate                 1233.0    812.504461   403.208379   102.0   477.0
# DistanceFromHome          1233.0      8.915653     8.012633     1.0     2.0
# Education                 1233.0      2.927007     1.027002     1.0     2.0
# EnvironmentSatisfaction   1233.0      2.771290     1.071132     1.0     2.0
# HourlyRate                1233.0     65.952149    20.380754    30.0    48.0
# JobInvolvement            1233.0      2.770479     0.692050     1.0     2.0
# JobLevel                  1233.0      2.145985     1.117933     1.0     1.0
# JobSatisfaction           1233.0      2.778589     1.093277     1.0     2.0
# MonthlyRate               1231.0  14263.154346  7106.411508  2094.0  7961.5
# ...

# %%
left_df = hr_df[hr_df['Attrition'] == "No"].describe()
stayed_df = hr_df[hr_df['Attrition'] == "Yes"].describe()

# %%
left_df
# Out:
#                Age  MonthlyIncome    DailyRate  DistanceFromHome    Education  \
# count  1233.000000    1231.000000  1233.000000       1233.000000  1233.000000
# mean     37.561233    6837.504468   812.504461          8.915653     2.927007
# std       8.888360    4820.415800   403.208379          8.012633     1.027002
# min      18.000000    1051.000000   102.000000          1.000000     1.000000
# 25%      31.000000    3211.500000   477.000000          2.000000     2.000000
# 50%      36.000000    5206.000000   817.000000          7.000000     3.000000
# 75%      43.000000    8835.500000  1176.000000         13.000000     4.000000
# max      60.000000   19999.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1233.000000  1233.000000     1233.000000  1233.000000
# mean                  2.771290    65.952149        2.770479     2.145985
# ...

# %%
stayed_df
# Out:
#               Age  MonthlyIncome    DailyRate  DistanceFromHome   Education  \
# count  237.000000     236.000000   237.000000        237.000000  237.000000
# mean    33.607595    4771.588983   750.362869         10.632911    2.839662
# std      9.689350    3640.097444   401.899519          8.452525    1.008244
# min     18.000000    1009.000000   103.000000          1.000000    1.000000
# 25%     28.000000    2371.500000   408.000000          3.000000    2.000000
# 50%     32.000000    3187.000000   699.000000          9.000000    3.000000
# 75%     39.000000    5850.000000  1092.000000         17.000000    4.000000
# max     58.000000   19859.000000  1496.000000         29.000000    5.000000
#
#        EnvironmentSatisfaction  HourlyRate  JobInvolvement    JobLevel  \
# count               237.000000  237.000000      237.000000  237.000000
# mean                  2.464135   65.573840        2.518987    1.637131
# ...

# %% [markdown]
# # CODING TASK #7. PANDAS WITH FUNCTIONS

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')
hr_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %% [markdown]
# - **Let's assume the daily rate has increased by 10%**
# - **Define a function that increases all clients networth by a fixed value of 10% (for simplicity sake)**
# - **assume that net worth increased by 10%**
# - **You can apply a function to the DataFrame**

# %%
hr_df['DailyRateIncrease'] = hr_df['DailyRate'].apply(lambda x: x * 1.1)

# %%
hr_df['DailyRateIncrease']
# Out:
# 0       1212.2
# 1        306.9
# 2       1510.3
# 3       1531.2
# 4        650.1
#          ...
# 1465     972.4
# 1466     674.3
# 1467     170.5
# 1468    1125.3
# 1469     690.8
# Name: DailyRateIncrease, Length: 1470, dtype: float64

# %%
hr_df['MonthlyIncomeIncrease'] = hr_df['MonthlyIncome'].apply(lambda x: x * 1.1)
hr_df['MonthlyIncomeIncrease']
# Out:
# 0        6592.3
# 1           NaN
# 2        2299.0
# 3        3199.9
# 4        3814.8
#          ...
# 1465     2828.1
# 1466    10990.1
# 1467     6756.2
# 1468     5929.0
# 1469     4844.4
# Name: MonthlyIncomeIncrease, Length: 1470, dtype: float64

# %% [markdown]
# **PRACTICE OPPORTUNITY #7:**
# - **Define a function that doubles the DailyRate and adds $100**
# - **Apply the function to the DataFrame**
# - **Calculate the updated total Daily Rate of all employees combined**

# %%
hr_df['DailyRateIncrease'] = hr_df['DailyRate'].transform(lambda x: x*2 +100) # apply or transform can be used

# %%
hr_df['DailyRateIncrease'].sum()
# Out:
# 2506308

# %% [markdown]
# # CODING TASK #8: HISTOGRAM AND CORRELATION

# %% [markdown]
# - **Several features such as 'MonthlyIncome' and 'TotalWorkingYears' are tail heavy**
# - **Job level is strongly correlated with total working hours**
# - **Monthly income is strongly correlated with Job level**
# - **Monthly income is strongly correlated with total working hours**
# - **Age is strongly correlated with monthly income**

# %%
hr_df.corr()
# Out:
#                                Age  MonthlyIncome  DailyRate  \
# Age                       1.000000       0.500915   0.010661
# MonthlyIncome             0.500915       1.000000   0.008020
# DailyRate                 0.010661       0.008020   1.000000
# DistanceFromHome         -0.001686      -0.017333  -0.004985
# Education                 0.208034       0.094755  -0.016806
# EmployeeCount                  NaN            NaN        NaN
# EmployeeNumber           -0.007392      -0.016276  -0.049582
# EnvironmentSatisfaction   0.010146      -0.005885   0.018355
# HourlyRate                0.024287      -0.015412   0.023381
# JobInvolvement            0.029820      -0.014619   0.046135
# JobLevel                  0.509604       0.950346   0.002966
# JobSatisfaction          -0.004892      -0.007983   0.030571
# MonthlyRate               0.028860       0.035034  -0.031775
# NumCompaniesWorked        0.299635       0.149371   0.038153
# ...

# %%
sns.heatmap(hr_df.corr());

# %%
sns.scatterplot(x=hr_df.MonthlyIncome, y=hr_df.TotalWorkingYears);

# %% [markdown]
# **PRACTICE OPPORTUNITY #8:**
# - **Change the color of the heatmap [External Research is Required]**

# %%
sns.heatmap(hr_df.corr(), cmap = "YlGnBu", center = 0.3);

# %% [markdown]
# # EXCELLENT JOB!

# %% [markdown]
# # FINAL CAPSTONE PROJECT OVERVIEW

# %% [markdown]
# - In this project, we will perform basic Exploratory Data Analysis (EDA) on the Kyphosis disease Dataset.
# - Kyphosis is an abnormally excessive convex curvature of the spine.
# - Dataset contains 81 rows and 4 columns representing data on children who have had corrective spinal surgery.
#     - INPUTS: 1. Age: in months, 2. Number: the number of vertebrae involved, 3. Start: the number of the first (topmost) vertebra operated on.
#     - OUTPUTS: Kyphosis which represents a factor with levels absent present indicating if a kyphosis (a type of deformation) was present after the operation.
# - Using the “kyphosis.csv" included in the course package, write a python script to perform the following tasks:
#     1. Import the “kyphosis.csv" file using Pandas
#     2. Perform basic Exploratory Data Analysis (EDA) on the data
#     3. List the average, minimum and maximum age (in years) considered in this study using 2 methods
#     4. Plot the correlation matrix
#     5. Convert the age column datatype from int64 to float64
#     6. Define a function that converts age from months to years
#     7. Apply the function to the “Age” column and add the results into a new column entitled “Age in Years”
#     8. What are the features of the oldest and youngest child in this study?
#     9. Scale the raw Age column (in months) using both standardization and Normalization. Perform a sanity check.
#     10. Normalization is conducted on the 'Age' column to make feature values range from 0 to 1.

# %%
ky_df=pd.read_csv("kyphosis.csv")
ky_df
# Out:
#    Kyphosis  Age  Number  Start
# 0    absent   71       3      5
# 1    absent  158       3     14
# 2   present  128       4      5
# 3    absent    2       5      1
# 4    absent    1       4     15
# ..      ...  ...     ...    ...
# 76  present  157       3     13
# 77   absent   26       7     13
# 78   absent  120       2     13
# 79  present   42       7      6
# 80   absent   36       4     13
#
# [81 rows x 4 columns]

# %%
ky_df.head(3)
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5

# %%
ky_df.tail(3)
# Out:
#    Kyphosis  Age  Number  Start
# 78   absent  120       2     13
# 79  present   42       7      6
# 80   absent   36       4     13

# %%
ky_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     int64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.7+ KB

# %%
ky_df.describe().T
# Out:
#         count       mean        std  min   25%   50%    75%    max
# Age      81.0  83.654321  58.104251  1.0  26.0  87.0  130.0  206.0
# Number   81.0   4.049383   1.619423  2.0   3.0   4.0    5.0   10.0
# Start    81.0  11.493827   4.883962  1.0   9.0  13.0   16.0   18.0

# %%
ky_df.Age.min()
# Out:
# 1

# %%
ky_df.Age.max()
# Out:
# 206

# %%
ky_df.Age.mean()
# Out:
# 83.65432098765432

# %%
ky_df.corr()
# Out:
#              Age    Number     Start
# Age     1.000000 -0.016687  0.057828
# Number -0.016687  1.000000 -0.425099
# Start   0.057828 -0.425099  1.000000

# %%
sns.heatmap(ky_df.corr(),annot = True, cmap = "cubehelix", center = 0.5 );

# %%
ky_df["Age"]=ky_df["Age"].astype(float)
ky_df
# Out:
#    Kyphosis    Age  Number  Start
# 0    absent   71.0       3      5
# 1    absent  158.0       3     14
# 2   present  128.0       4      5
# 3    absent    2.0       5      1
# 4    absent    1.0       4     15
# ..      ...    ...     ...    ...
# 76  present  157.0       3     13
# 77   absent   26.0       7     13
# 78   absent  120.0       2     13
# 79  present   42.0       7      6
# 80   absent   36.0       4     13
#
# [81 rows x 4 columns]

# %%
convert_to_years=lambda x: round(x/12)

# %%
ky_df["Age_year"]=ky_df["Age"].apply(convert_to_years)

# %%
ky_df
# Out:
#    Kyphosis    Age  Number  Start  Age_year
# 0    absent   71.0       3      5         6
# 1    absent  158.0       3     14        13
# 2   present  128.0       4      5        11
# 3    absent    2.0       5      1         0
# 4    absent    1.0       4     15         0
# ..      ...    ...     ...    ...       ...
# 76  present  157.0       3     13        13
# 77   absent   26.0       7     13         2
# 78   absent  120.0       2     13        10
# 79  present   42.0       7      6         4
# 80   absent   36.0       4     13         3
#
# [81 rows x 5 columns]

# %%
oldest = ky_df.loc[ky_df['Age_year'].idxmax()]
youngest = ky_df.loc[ky_df['Age_year'].idxmin()]

# %%
oldest
# Out:
# Kyphosis    absent
# Age          206.0
# Number           4
# Start           10
# Age_year        17
# Name: 73, dtype: object

# %%
youngest
# Out:
# Kyphosis    absent
# Age            2.0
# Number           5
# Start            1
# Age_year         0
# Name: 3, dtype: object

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
ky_df['Age'] = scaler.fit_transform(ky_df['Age'].values.reshape(-1,1))

# %%
ky_df['Age'].tail(10)
# Out:
# 71    0.614634
# 72    0.419512
# 73    1.000000
# 74    0.048780
# 75    0.863415
# 76    0.760976
# 77    0.121951
# 78    0.580488
# 79    0.200000
# 80    0.170732
# Name: Age, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
ky_df["Age"] = scaler.fit_transform(ky_df["Age"].values.reshape(-1,1))
ky_df["Age"].head(20)
# Out:
# 0    -0.219143
# 1     1.287494
# 2     0.767964
# 3    -1.414063
# 4    -1.431381
# 5    -1.431381
# 6    -0.392320
# 7    -0.807944
# 8     0.508199
# 9    -0.426956
# 10   -0.028649
# 11    1.114318
# 12   -1.136980
# 13   -1.431381
# 14    1.460671
# 15   -1.431381
# 16   -0.097920
# 17    1.581895
# 18   -0.063284
# 19   -0.981121
# Name: Age, dtype: float64

# %%
sns.histplot(x=ky_df["Age_year"],kde=True,bins=20, color="orange");
